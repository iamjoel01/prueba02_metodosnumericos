# %% [markdown]
# # Ejercicio 3
# Nombre: Joel Quilumba

# %%
# %load_ext autoreload

# %% [markdown]
# # Examen
# ## Gauss-Jacobi y Gauss-Seidel

# %%
# %autoreload 2
from src import eliminacion_gaussiana, matriz_aumentada
A = [[1, 1], [-2, 5]]
b = [7, 0]
eliminacion_gaussiana(matriz_aumentada(A, b))
# Out:
# [07-19 22:44:01][INFO] 2024-07-19 22:44:01.676072
# [07-19 22:44:01][INFO] 2024-07-19 22:44:01.677072
# [07-19 22:44:01][INFO] 2024-07-19 22:44:01.679071
# [07-19 22:44:01][INFO]
# [[ 1.  1.  7.]
#  [ 0.  7. 14.]]
# array([5., 2.])

# %%
# %autoreload 2
from src import gauss_jacobi
A = [[1, 1], [-2, 5]]
b = [7, 0]
n = len(A)

gauss_jacobi(A=A, b=b, x0=[0]*n, tol=1e-5, max_iter=1000)
# Out:
# [07-19 22:53:31][INFO] Iteración 0: [7. 0.]
# [07-19 22:53:31][INFO] Iteración 1: [7.  2.8]
# [07-19 22:53:31][INFO] Iteración 2: [4.2 2.8]
# [07-19 22:53:31][INFO] Iteración 3: [4.2  1.68]
# [07-19 22:53:31][INFO] Iteración 4: [5.32 1.68]
# [07-19 22:53:31][INFO] Iteración 5: [5.32  2.128]
# [07-19 22:53:31][INFO] Iteración 6: [4.872 2.128]
# [07-19 22:53:31][INFO] Iteración 7: [4.872  1.9488]
# [07-19 22:53:31][INFO] Iteración 8: [5.0512 1.9488]
# [07-19 22:53:31][INFO] Iteración 9: [5.0512  2.02048]
# [07-19 22:53:31][INFO] Iteración 10: [4.97952 2.02048]
# [07-19 22:53:31][INFO] Iteración 11: [4.97952  1.991808]
# [07-19 22:53:31][INFO] Iteración 12: [5.008192 1.991808]
# [07-19 22:53:31][INFO] Iteración 13: [5.008192  2.0032768]
# [07-19 22:53:31][INFO] Iteración 14: [4.9967232 2.0032768]
# [07-19 22:53:31][INFO] Iteración 15: [4.9967232  1.99868928]
# [07-19 22:53:31][INFO] Iteración 16: [5.00131072 1.99868928]
# [07-19 22:53:31][INFO] Iteración 17: [5.00131072 2.00052429]
# [07-19 22:53:31][INFO] Iteración 18: [4.99947571 2.00052429]
# [07-19 22:53:31][INFO] Iteración 19: [4.99947571 1.99979028]
# [07-19 22:53:31][INFO] Iteración 20: [5.00020972 1.99979028]
# [07-19 22:53:31][INFO] Iteración 21: [5.00020972 2.00008389]
# [07-19 22:53:31][INFO] Iteración 22: [4.99991611 2.00008389]
# [07-19 22:53:31][INFO] Iteración 23: [4.99991611 1.99996645]
# [07-19 22:53:31][INFO] Iteración 24: [5.00003355 1.99996645]
# [07-19 22:53:31][INFO] Iteración 25: [5.00003355 2.00001342]
# [07-19 22:53:31][INFO] Iteración 26: [4.99998658 2.00001342]
# [07-19 22:53:31][INFO] Iteración 27: [4.99998658 1.99999463]
# [07-19 22:53:31][INFO] Iteración 28: [5.00000537 1.99999463]
# (array([5.00000537, 2.00000215]),
#  [array([0., 0.]),
#   array([7., 0.]),
#   array([7. , 2.8]),
#   array([4.2, 2.8]),
#   array([4.2 , 1.68]),
#   array([5.32, 1.68]),
#   array([5.32 , 2.128]),
#   array([4.872, 2.128]),
#   array([4.872 , 1.9488]),
#   array([5.0512, 1.9488]),
#   array([5.0512 , 2.02048]),
#   array([4.97952, 2.02048]),
#   array([4.97952 , 1.991808]),
#   array([5.008192, 1.991808]),
#   array([5.008192 , 2.0032768]),
#   array([4.9967232, 2.0032768]),
#   array([4.9967232 , 1.99868928]),
#   array([5.00131072, 1.99868928]),
#   array([5.00131072, 2.00052429]),
#   array([4.99947571, 2.00052429]),
#   array([4.99947571, 1.99979028]),
#   array([5.00020972, 1.99979028]),
#   array([5.00020972, 2.00008389]),
#   array([4.99991611, 2.00008389]),
#   array([4.99991611, 1.99996645]),
#   array([5.00003355, 1.99996645]),
#   array([5.00003355, 2.00001342]),
#   array([4.99998658, 2.00001342]),
#   array([4.99998658, 1.99999463]),
#   array([5.00000537, 1.99999463])])

# %% [markdown]
# ![alt text](assets/trayectoria.png)

# %% [markdown]
# ## Grafique

# %%
# Cargar extensiones para autoreload
# %load_ext autoreload
# %autoreload 2

# Importar las funciones necesarias desde src
from src.iterative_methods import gauss_jacobi, gauss_seidel
import numpy as np
import matplotlib.pyplot as plt

# Función para graficar la trayectoria
def plot_trajectory(trajectory, solution, method):
    # Imprimir la forma de cada elemento en la trayectoria
    for i, t in enumerate(trajectory):
        print(f'Forma de trajectory[{i}]: {np.array(t).shape}')
        
    # Asegurarse de que cada elemento en la trayectoria sea un vector de dos elementos
    trajectory = [np.array(t) for t in trajectory if len(t) == 2]
    
    trajectory = np.array(trajectory)
    plt.plot(trajectory[:, 0], trajectory[:, 1], marker='o', label=f'{method} trayectoria')
    plt.plot(solution[0], solution[1], 'ro', label='solución')
    plt.xlabel('$x_1$')
    plt.ylabel('$x_2$')
    plt.legend()
    plt.grid()
    plt.title(f'Trayectoria del método {method}')
    plt.show()

# Sistema de ecuaciones 1
A1 = np.array([[1, 1], [-2, 5]])
b1 = np.array([7, 0])
x0 = np.array([1, 1])

# Gauss-Jacobi
solution_jacobi, trajectory_jacobi = gauss_jacobi(A=A1, b=b1, x0=x0, tol=1e-5, max_iter=100)
print(f'Solución Gauss-Jacobi: {solution_jacobi}')
plot_trajectory(trajectory_jacobi, solution_jacobi, 'Gauss-Jacobi')

# Sistema de ecuaciones 2
A2 = np.array([[1, 1], [-2, 1]])
b2 = np.array([6, 0])

# Gauss-Jacobi
solution_jacobi_2, trajectory_jacobi_2 = gauss_jacobi(A=A2, b=b2, x0=x0, tol=1e-5, max_iter=100)
print(f'Solución Gauss-Jacobi: {solution_jacobi_2}')
plot_trajectory(trajectory_jacobi_2, solution_jacobi_2, 'Gauss-Jacobi')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [07-19 22:55:29][INFO] Iteración 0: [6.  0.4]
# [07-19 22:55:29][INFO] Iteración 1: [6.6 2.4]
# [07-19 22:55:29][INFO] Iteración 2: [4.6  2.64]
# [07-19 22:55:29][INFO] Iteración 3: [4.36 1.84]
# [07-19 22:55:29][INFO] Iteración 4: [5.16  1.744]
# [07-19 22:55:29][INFO] Iteración 5: [5.256 2.064]
# [07-19 22:55:29][INFO] Iteración 6: [4.936  2.1024]
# [07-19 22:55:29][INFO] Iteración 7: [4.8976 1.9744]
# [07-19 22:55:29][INFO] Iteración 8: [5.0256  1.95904]
# [07-19 22:55:29][INFO] Iteración 9: [5.04096 2.01024]
# [07-19 22:55:29][INFO] Iteración 10: [4.98976  2.016384]
# [07-19 22:55:29][INFO] Iteración 11: [4.983616 1.995904]
# [07-19 22:55:29][INFO] Iteración 12: [5.004096  1.9934464]
# [07-19 22:55:29][INFO] Iteración 13: [5.0065536 2.0016384]
# [07-19 22:55:29][INFO] Iteración 14: [4.9983616  2.00262144]
# [07-19 22:55:29][INFO] Iteración 15: [4.99737856 1.99934464]
# [07-19 22:55:29][INFO] Iteración 16: [5.00065536 1.99895142]
# [07-19 22:55:29][INFO] Iteración 17: [5.00104858 2.00026214]
# [07-19 22:55:29][INFO] Iteración 18: [4.99973786 2.00041943]
# [07-19 22:55:29][INFO] Iteración 19: [4.99958057 1.99989514]
# [07-19 22:55:29][INFO] Iteración 20: [5.00010486 1.99983223]
# [07-19 22:55:29][INFO] Iteración 21: [5.00016777 2.00004194]
# [07-19 22:55:29][INFO] Iteración 22: [4.99995806 2.00006711]
# [07-19 22:55:29][INFO] Iteración 23: [4.99993289 1.99998322]
# [07-19 22:55:29][INFO] Iteración 24: [5.00001678 1.99997316]
# [07-19 22:55:29][INFO] Iteración 25: [5.00002684 2.00000671]
# [07-19 22:55:29][INFO] Iteración 26: [4.99999329 2.00001074]
# [07-19 22:55:29][INFO] Iteración 27: [4.99998926 1.99999732]
# [07-19 22:55:29][INFO] Iteración 28: [5.00000268 1.99999571]
# Solución Gauss-Jacobi: [5.00000429 2.00000107]
# Forma de trajectory[0]: (2,)
# Forma de trajectory[1]: (2,)
# Forma de trajectory[2]: (2,)
# Forma de trajectory[3]: (2,)
# Forma de trajectory[4]: (2,)
# Forma de trajectory[5]: (2,)
# Forma de trajectory[6]: (2,)
# Forma de trajectory[7]: (2,)
# Forma de trajectory[8]: (2,)
# Forma de trajectory[9]: (2,)
# Forma de trajectory[10]: (2,)
# Forma de trajectory[11]: (2,)
# Forma de trajectory[12]: (2,)
# Forma de trajectory[13]: (2,)
# Forma de trajectory[14]: (2,)
# Forma de trajectory[15]: (2,)
# Forma de trajectory[16]: (2,)
# Forma de trajectory[17]: (2,)
# Forma de trajectory[18]: (2,)
# Forma de trajectory[19]: (2,)
# Forma de trajectory[20]: (2,)
# Forma de trajectory[21]: (2,)
# Forma de trajectory[22]: (2,)
# Forma de trajectory[23]: (2,)
# Forma de trajectory[24]: (2,)
# Forma de trajectory[25]: (2,)
# Forma de trajectory[26]: (2,)
# Forma de trajectory[27]: (2,)
# Forma de trajectory[28]: (2,)
# Forma de trajectory[29]: (2,)
# [07-19 22:55:29][INFO] Iteración 0: [5. 2.]
# [07-19 22:55:29][INFO] Iteración 1: [ 4. 10.]
# [07-19 22:55:29][INFO] Iteración 2: [-4.  8.]
# [07-19 22:55:29][INFO] Iteración 3: [-2. -8.]
# [07-19 22:55:29][INFO] Iteración 4: [14. -4.]
# [07-19 22:55:29][INFO] Iteración 5: [10. 28.]
# [07-19 22:55:29][INFO] Iteración 6: [-22.  20.]
# [07-19 22:55:29][INFO] Iteración 7: [-14. -44.]
# [07-19 22:55:29][INFO] Iteración 8: [ 50. -28.]
# [07-19 22:55:29][INFO] Iteración 9: [ 34. 100.]
# [07-19 22:55:29][INFO] Iteración 10: [-94.  68.]
# [07-19 22:55:29][INFO] Iteración 11: [ -62. -188.]
# [07-19 22:55:29][INFO] Iteración 12: [ 194. -124.]
# [07-19 22:55:29][INFO] Iteración 13: [130. 388.]
# [07-19 22:55:29][INFO] Iteración 14: [-382.  260.]
# [07-19 22:55:29][INFO] Iteración 15: [-254. -764.]
# [07-19 22:55:29][INFO] Iteración 16: [ 770. -508.]
# [07-19 22:55:29][INFO] Iteración 17: [ 514. 1540.]
# [07-19 22:55:29][INFO] Iteración 18: [-1534.  1028.]
# [07-19 22:55:29][INFO] Iteración 19: [-1022. -3068.]
# [07-19 22:55:29][INFO] Iteración 20: [ 3074. -2044.]
# [07-19 22:55:29][INFO] Iteración 21: [2050. 6148.]
# [07-19 22:55:29][INFO] Iteración 22: [-6142.  4100.]
# [07-19 22:55:29][INFO] Iteración 23: [ -4094. -12284.]
# [07-19 22:55:29][INFO] Iteración 24: [12290. -8188.]
# [07-19 22:55:29][INFO] Iteración 25: [ 8194. 24580.]
# [07-19 22:55:29][INFO] Iteración 26: [-24574.  16388.]
# [07-19 22:55:29][INFO] Iteración 27: [-16382. -49148.]
# [07-19 22:55:29][INFO] Iteración 28: [ 49154. -32764.]
# [07-19 22:55:29][INFO] Iteración 29: [32770. 98308.]
# [07-19 22:55:29][INFO] Iteración 30: [-98302.  65540.]
# [07-19 22:55:29][INFO] Iteración 31: [ -65534. -196604.]
# [07-19 22:55:29][INFO] Iteración 32: [ 196610. -131068.]
# [07-19 22:55:29][INFO] Iteración 33: [131074. 393220.]
# [07-19 22:55:29][INFO] Iteración 34: [-393214.  262148.]
# [07-19 22:55:29][INFO] Iteración 35: [-262142. -786428.]
# [07-19 22:55:29][INFO] Iteración 36: [ 786434. -524284.]
# [07-19 22:55:29][INFO] Iteración 37: [ 524290. 1572868.]
# [07-19 22:55:29][INFO] Iteración 38: [-1572862.  1048580.]
# [07-19 22:55:29][INFO] Iteración 39: [-1048574. -3145724.]
# [07-19 22:55:29][INFO] Iteración 40: [ 3145730. -2097148.]
# [07-19 22:55:29][INFO] Iteración 41: [2097154. 6291460.]
# [07-19 22:55:29][INFO] Iteración 42: [-6291454.  4194308.]
# [07-19 22:55:29][INFO] Iteración 43: [ -4194302. -12582908.]
# [07-19 22:55:29][INFO] Iteración 44: [12582914. -8388604.]
# [07-19 22:55:29][INFO] Iteración 45: [ 8388610. 25165828.]
# [07-19 22:55:29][INFO] Iteración 46: [-25165822.  16777220.]
# [07-19 22:55:29][INFO] Iteración 47: [-16777214. -50331644.]
# [07-19 22:55:29][INFO] Iteración 48: [ 50331650. -33554428.]
# [07-19 22:55:29][INFO] Iteración 49: [3.3554434e+07 1.0066330e+08]
# [07-19 22:55:29][INFO] Iteración 50: [-1.00663294e+08  6.71088680e+07]
# [07-19 22:55:29][INFO] Iteración 51: [-6.71088620e+07 -2.01326588e+08]
# [07-19 22:55:29][INFO] Iteración 52: [ 2.01326594e+08 -1.34217724e+08]
# [07-19 22:55:29][INFO] Iteración 53: [1.34217730e+08 4.02653188e+08]
# [07-19 22:55:29][INFO] Iteración 54: [-4.02653182e+08  2.68435460e+08]
# [07-19 22:55:29][INFO] Iteración 55: [-2.68435454e+08 -8.05306364e+08]
# [07-19 22:55:29][INFO] Iteración 56: [ 8.05306370e+08 -5.36870908e+08]
# [07-19 22:55:29][INFO] Iteración 57: [5.36870914e+08 1.61061274e+09]
# [07-19 22:55:29][INFO] Iteración 58: [-1.61061273e+09  1.07374183e+09]
# [07-19 22:55:29][INFO] Iteración 59: [-1.07374182e+09 -3.22122547e+09]
# [07-19 22:55:29][INFO] Iteración 60: [ 3.22122547e+09 -2.14748364e+09]
# [07-19 22:55:29][INFO] Iteración 61: [2.14748365e+09 6.44245095e+09]
# [07-19 22:55:29][INFO] Iteración 62: [-6.44245094e+09  4.29496730e+09]
# [07-19 22:55:29][INFO] Iteración 63: [-4.29496729e+09 -1.28849019e+10]
# [07-19 22:55:29][INFO] Iteración 64: [ 1.28849019e+10 -8.58993459e+09]
# [07-19 22:55:29][INFO] Iteración 65: [8.58993459e+09 2.57698038e+10]
# [07-19 22:55:29][INFO] Iteración 66: [-2.57698038e+10  1.71798692e+10]
# [07-19 22:55:29][INFO] Iteración 67: [-1.71798692e+10 -5.15396075e+10]
# [07-19 22:55:29][INFO] Iteración 68: [ 5.15396076e+10 -3.43597384e+10]
# [07-19 22:55:29][INFO] Iteración 69: [3.43597384e+10 1.03079215e+11]
# [07-19 22:55:29][INFO] Iteración 70: [-1.03079215e+11  6.87194767e+10]
# [07-19 22:55:29][INFO] Iteración 71: [-6.87194767e+10 -2.06158430e+11]
# [07-19 22:55:29][INFO] Iteración 72: [ 2.06158430e+11 -1.37438953e+11]
# [07-19 22:55:29][INFO] Iteración 73: [1.37438953e+11 4.12316860e+11]
# [07-19 22:55:29][INFO] Iteración 74: [-4.12316860e+11  2.74877907e+11]
# [07-19 22:55:29][INFO] Iteración 75: [-2.74877907e+11 -8.24633721e+11]
# [07-19 22:55:29][INFO] Iteración 76: [ 8.24633721e+11 -5.49755814e+11]
# [07-19 22:55:29][INFO] Iteración 77: [5.49755814e+11 1.64926744e+12]
# [07-19 22:55:29][INFO] Iteración 78: [-1.64926744e+12  1.09951163e+12]
# [07-19 22:55:29][INFO] Iteración 79: [-1.09951163e+12 -3.29853488e+12]
# [07-19 22:55:29][INFO] Iteración 80: [ 3.29853488e+12 -2.19902326e+12]
# [07-19 22:55:29][INFO] Iteración 81: [2.19902326e+12 6.59706977e+12]
# [07-19 22:55:29][INFO] Iteración 82: [-6.59706977e+12  4.39804651e+12]
# [07-19 22:55:29][INFO] Iteración 83: [-4.39804651e+12 -1.31941395e+13]
# [07-19 22:55:29][INFO] Iteración 84: [ 1.31941395e+13 -8.79609302e+12]
# [07-19 22:55:29][INFO] Iteración 85: [8.79609302e+12 2.63882791e+13]
# [07-19 22:55:30][INFO] Iteración 86: [-2.63882791e+13  1.75921860e+13]
# [07-19 22:55:30][INFO] Iteración 87: [-1.75921860e+13 -5.27765581e+13]
# [07-19 22:55:30][INFO] Iteración 88: [ 5.27765581e+13 -3.51843721e+13]
# [07-19 22:55:30][INFO] Iteración 89: [3.51843721e+13 1.05553116e+14]
# [07-19 22:55:30][INFO] Iteración 90: [-1.05553116e+14  7.03687442e+13]
# [07-19 22:55:30][INFO] Iteración 91: [-7.03687442e+13 -2.11106233e+14]
# [07-19 22:55:30][INFO] Iteración 92: [ 2.11106233e+14 -1.40737488e+14]
# [07-19 22:55:30][INFO] Iteración 93: [1.40737488e+14 4.22212465e+14]
# [07-19 22:55:30][INFO] Iteración 94: [-4.22212465e+14  2.81474977e+14]
# [07-19 22:55:30][INFO] Iteración 95: [-2.81474977e+14 -8.44424930e+14]
# [07-19 22:55:30][INFO] Iteración 96: [ 8.44424930e+14 -5.62949953e+14]
# [07-19 22:55:30][INFO] Iteración 97: [5.62949953e+14 1.68884986e+15]
# [07-19 22:55:30][INFO] Iteración 98: [-1.68884986e+15  1.12589991e+15]
# [07-19 22:55:30][INFO] Iteración 99: [-1.12589991e+15 -3.37769972e+15]
# Solución Gauss-Jacobi: [-1.12589991e+15 -3.37769972e+15]
# Forma de trajectory[0]: (2,)
# Forma de trajectory[1]: (2,)
# Forma de trajectory[2]: (2,)
# Forma de trajectory[3]: (2,)
# Forma de trajectory[4]: (2,)
# Forma de trajectory[5]: (2,)
# Forma de trajectory[6]: (2,)
# Forma de trajectory[7]: (2,)
# Forma de trajectory[8]: (2,)
# Forma de trajectory[9]: (2,)
# Forma de trajectory[10]: (2,)
# Forma de trajectory[11]: (2,)
# Forma de trajectory[12]: (2,)
# Forma de trajectory[13]: (2,)
# Forma de trajectory[14]: (2,)
# Forma de trajectory[15]: (2,)
# Forma de trajectory[16]: (2,)
# Forma de trajectory[17]: (2,)
# Forma de trajectory[18]: (2,)
# Forma de trajectory[19]: (2,)
# Forma de trajectory[20]: (2,)
# Forma de trajectory[21]: (2,)
# Forma de trajectory[22]: (2,)
# Forma de trajectory[23]: (2,)
# Forma de trajectory[24]: (2,)
# Forma de trajectory[25]: (2,)
# Forma de trajectory[26]: (2,)
# Forma de trajectory[27]: (2,)
# Forma de trajectory[28]: (2,)
# Forma de trajectory[29]: (2,)
# Forma de trajectory[30]: (2,)
# Forma de trajectory[31]: (2,)
# Forma de trajectory[32]: (2,)
# Forma de trajectory[33]: (2,)
# Forma de trajectory[34]: (2,)
# Forma de trajectory[35]: (2,)
# Forma de trajectory[36]: (2,)
# Forma de trajectory[37]: (2,)
# Forma de trajectory[38]: (2,)
# Forma de trajectory[39]: (2,)
# Forma de trajectory[40]: (2,)
# Forma de trajectory[41]: (2,)
# Forma de trajectory[42]: (2,)
# Forma de trajectory[43]: (2,)
# Forma de trajectory[44]: (2,)
# Forma de trajectory[45]: (2,)
# Forma de trajectory[46]: (2,)
# Forma de trajectory[47]: (2,)
# Forma de trajectory[48]: (2,)
# Forma de trajectory[49]: (2,)
# Forma de trajectory[50]: (2,)
# Forma de trajectory[51]: (2,)
# Forma de trajectory[52]: (2,)
# Forma de trajectory[53]: (2,)
# Forma de trajectory[54]: (2,)
# Forma de trajectory[55]: (2,)
# Forma de trajectory[56]: (2,)
# Forma de trajectory[57]: (2,)
# Forma de trajectory[58]: (2,)
# Forma de trajectory[59]: (2,)
# Forma de trajectory[60]: (2,)
# Forma de trajectory[61]: (2,)
# Forma de trajectory[62]: (2,)
# Forma de trajectory[63]: (2,)
# Forma de trajectory[64]: (2,)
# Forma de trajectory[65]: (2,)
# Forma de trajectory[66]: (2,)
# Forma de trajectory[67]: (2,)
# Forma de trajectory[68]: (2,)
# Forma de trajectory[69]: (2,)
# Forma de trajectory[70]: (2,)
# Forma de trajectory[71]: (2,)
# Forma de trajectory[72]: (2,)
# Forma de trajectory[73]: (2,)
# Forma de trajectory[74]: (2,)
# Forma de trajectory[75]: (2,)
# Forma de trajectory[76]: (2,)
# Forma de trajectory[77]: (2,)
# Forma de trajectory[78]: (2,)
# Forma de trajectory[79]: (2,)
# Forma de trajectory[80]: (2,)
# Forma de trajectory[81]: (2,)
# Forma de trajectory[82]: (2,)
# Forma de trajectory[83]: (2,)
# Forma de trajectory[84]: (2,)
# Forma de trajectory[85]: (2,)
# Forma de trajectory[86]: (2,)
# Forma de trajectory[87]: (2,)
# Forma de trajectory[88]: (2,)
# Forma de trajectory[89]: (2,)
# Forma de trajectory[90]: (2,)
# Forma de trajectory[91]: (2,)
# Forma de trajectory[92]: (2,)
# Forma de trajectory[93]: (2,)
# Forma de trajectory[94]: (2,)
# Forma de trajectory[95]: (2,)
# Forma de trajectory[96]: (2,)
# Forma de trajectory[97]: (2,)
# Forma de trajectory[98]: (2,)
# Forma de trajectory[99]: (2,)
# Forma de trajectory[100]: (2,)

# %% [markdown]
# ## Gauss-Seidel

# %%
# %autoreload 2
from src import gauss_seidel
# ---------- 
A = [[1, 1], [-2, 5]]
b = [7, 0]
n = len(b)
gauss_seidel(A=A, b=b, x0=[0]*n, tol=1e-5, max_iter=1000)
# Out:
# [07-19 19:00:34][INFO] i= 0 x: [0. 0.]
# [07-19 19:00:34][INFO] i= 1 x: [[7.  2.8]]
# [07-19 19:00:34][INFO] i= 2 x: [[4.2  1.68]]
# [07-19 19:00:34][INFO] i= 3 x: [[5.32  2.128]]
# [07-19 19:00:34][INFO] i= 4 x: [[4.872  1.9488]]
# [07-19 19:00:34][INFO] i= 5 x: [[5.0512  2.02048]]
# [07-19 19:00:34][INFO] i= 6 x: [[4.97952  1.991808]]
# [07-19 19:00:34][INFO] i= 7 x: [[5.008192  2.0032768]]
# [07-19 19:00:34][INFO] i= 8 x: [[4.9967232  1.99868928]]
# [07-19 19:00:34][INFO] i= 9 x: [[5.00131072 2.00052429]]
# [07-19 19:00:34][INFO] i= 10 x: [[4.99947571 1.99979028]]
# [07-19 19:00:34][INFO] i= 11 x: [[5.00020972 2.00008389]]
# [07-19 19:00:34][INFO] i= 12 x: [[4.99991611 1.99996645]]
# [07-19 19:00:34][INFO] i= 13 x: [[5.00003355 2.00001342]]
# [07-19 19:00:34][INFO] i= 14 x: [[4.99998658 1.99999463]]
# [07-19 19:00:34][INFO] i= 15 x: [[5.00000537 2.00000215]]
# array([[4.99999785],
#        [1.99999914]])

# %% [markdown]
# ## Grafique el método de Gauss-Seidel

# %%
# Cargar extensiones para autoreload
# %load_ext autoreload
# %autoreload 2

# Importar las funciones necesarias desde src
from src.iterative_methods import gauss_jacobi, gauss_seidel
import numpy as np
import matplotlib.pyplot as plt

# Función para graficar la trayectoria
def plot_trajectory(trajectory, solution, method):
    # Imprimir la forma de cada elemento en la trayectoria
    for i, t in enumerate(trajectory):
        print(f'Forma de trajectory[{i}]: {np.array(t).shape}')
        
    # Asegurarse de que cada elemento en la trayectoria sea un vector de dos elementos
    trajectory = [np.array(t) for t in trajectory if len(t) == 2]
    
    trajectory = np.array(trajectory)
    plt.plot(trajectory[:, 0], trajectory[:, 1], marker='o', label=f'{method} trayectoria')
    plt.plot(solution[0], solution[1], 'ro', label='solución')
    plt.xlabel('$x_1$')
    plt.ylabel('$x_2$')
    plt.legend()
    plt.grid()
    plt.title(f'Trayectoria del método {method}')
    plt.show()

# Sistema de ecuaciones 1
A1 = np.array([[1, 1], [-2, 5]])
b1 = np.array([7, 0])
x0 = np.array([1, 1])


# Gauss-Seidel
solution_seidel, trajectory_seidel = gauss_seidel(A=A1, b=b1, x0=x0, tol=1e-5, max_iter=100)
print(f'Solución Gauss-Seidel: {solution_seidel}')
plot_trajectory(trajectory_seidel, solution_seidel, 'Gauss-Seidel')

# Sistema de ecuaciones 2
A2 = np.array([[1, 1], [-2, 1]])
b2 = np.array([6, 0])

# Gauss-Seidel
solution_seidel_2, trajectory_seidel_2 = gauss_seidel(A=A2, b=b2, x0=x0, tol=1e-5, max_iter=100)
print(f'Solución Gauss-Seidel: {solution_seidel_2}')
plot_trajectory(trajectory_seidel_2, solution_seidel_2, 'Gauss-Seidel')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [07-19 22:55:55][INFO] Iteración 0: [6 2]
# [07-19 22:55:55][INFO] Iteración 1: [5 2]
# Solución Gauss-Seidel: [5 2]
# Forma de trajectory[0]: (2,)
# Forma de trajectory[1]: (2,)
# Forma de trajectory[2]: (2,)
# [07-19 22:55:56][INFO] Iteración 0: [ 5 10]
# [07-19 22:55:56][INFO] Iteración 1: [-4 -8]
# [07-19 22:55:56][INFO] Iteración 2: [14 28]
# [07-19 22:55:56][INFO] Iteración 3: [-22 -44]
# [07-19 22:55:56][INFO] Iteración 4: [ 50 100]
# [07-19 22:55:56][INFO] Iteración 5: [ -94 -188]
# [07-19 22:55:56][INFO] Iteración 6: [194 388]
# [07-19 22:55:56][INFO] Iteración 7: [-382 -764]
# [07-19 22:55:56][INFO] Iteración 8: [ 770 1540]
# [07-19 22:55:56][INFO] Iteración 9: [-1534 -3068]
# [07-19 22:55:56][INFO] Iteración 10: [3074 6148]
# [07-19 22:55:56][INFO] Iteración 11: [ -6142 -12284]
# [07-19 22:55:56][INFO] Iteración 12: [12290 24580]
# [07-19 22:55:56][INFO] Iteración 13: [-24574 -49148]
# [07-19 22:55:56][INFO] Iteración 14: [49154 98308]
# [07-19 22:55:56][INFO] Iteración 15: [ -98302 -196604]
# [07-19 22:55:56][INFO] Iteración 16: [196610 393220]
# [07-19 22:55:56][INFO] Iteración 17: [-393214 -786428]
# [07-19 22:55:56][INFO] Iteración 18: [ 786434 1572868]
# [07-19 22:55:56][INFO] Iteración 19: [-1572862 -3145724]
# [07-19 22:55:56][INFO] Iteración 20: [3145730 6291460]
# [07-19 22:55:56][INFO] Iteración 21: [ -6291454 -12582908]
# [07-19 22:55:56][INFO] Iteración 22: [12582914 25165828]
# [07-19 22:55:56][INFO] Iteración 23: [-25165822 -50331644]
# [07-19 22:55:56][INFO] Iteración 24: [ 50331650 100663300]
# [07-19 22:55:56][INFO] Iteración 25: [-100663294 -201326588]
# [07-19 22:55:56][INFO] Iteración 26: [201326594 402653188]
# [07-19 22:55:56][INFO] Iteración 27: [-402653182 -805306364]
# [07-19 22:55:56][INFO] Iteración 28: [ 805306370 1610612740]
# [07-19 22:55:56][INFO] Iteración 29: [-1610612734  1073741828]
# [07-19 22:55:56][INFO] Iteración 30: [-1073741822 -2147483644]
# [07-19 22:55:56][INFO] Iteración 31: [-2147483646           4]
# [07-19 22:55:56][INFO] Iteración 32: [2 4]
# Solución Gauss-Seidel: [2 4]
# Forma de trajectory[0]: (2,)
# Forma de trajectory[1]: (2,)
# Forma de trajectory[2]: (2,)
# Forma de trajectory[3]: (2,)
# Forma de trajectory[4]: (2,)
# Forma de trajectory[5]: (2,)
# Forma de trajectory[6]: (2,)
# Forma de trajectory[7]: (2,)
# Forma de trajectory[8]: (2,)
# Forma de trajectory[9]: (2,)
# Forma de trajectory[10]: (2,)
# Forma de trajectory[11]: (2,)
# Forma de trajectory[12]: (2,)
# Forma de trajectory[13]: (2,)
# Forma de trajectory[14]: (2,)
# Forma de trajectory[15]: (2,)
# Forma de trajectory[16]: (2,)
# Forma de trajectory[17]: (2,)
# Forma de trajectory[18]: (2,)
# Forma de trajectory[19]: (2,)
# Forma de trajectory[20]: (2,)
# Forma de trajectory[21]: (2,)
# Forma de trajectory[22]: (2,)
# Forma de trajectory[23]: (2,)
# Forma de trajectory[24]: (2,)
# Forma de trajectory[25]: (2,)
# Forma de trajectory[26]: (2,)
# Forma de trajectory[27]: (2,)
# Forma de trajectory[28]: (2,)
# Forma de trajectory[29]: (2,)
# Forma de trajectory[30]: (2,)
# Forma de trajectory[31]: (2,)
# Forma de trajectory[32]: (2,)
# Forma de trajectory[33]: (2,)
# C:\Users\joelq\Videos\MN-prueba02-main\MN-prueba02-main\src\iterative_methods.py:121: RuntimeWarning: overflow encountered in scalar subtract
#   x_new[i] = (b[i] - suma) / A[i, i]

# %% [markdown]
# # Resuelva
#
# $ x_1 + x_2 = 6$
#
# $  -2 x_1 +  x_2 = 0$

# %%
# -*- coding: utf-8 -*-
"""
Python 3
19 / 07 / 2024
@author: z_tjona
"""

# ----------------------------- logging --------------------------
import logging
from sys import stdout
from datetime import datetime

logging.basicConfig(
    level=logging.INFO,
    format="[%(asctime)s][%(levelname)s] %(message)s",
    stream=stdout,
    datefmt="%m-%d %H:%M:%S",
)
logging.info(datetime.now())

import numpy as np
import matplotlib.pyplot as plt

# Definir los métodos iterativos
def gauss_jacobi(
    *, A: np.array, b: np.array, x0: np.array, tol: float, max_iter: int
) -> tuple:
    n = A.shape[0]
    x = x0.copy()
    trajectory = [x.copy()]

    for k in range(max_iter):
        x_new = np.zeros(n)
        for i in range(n):
            suma = np.sum(A[i, :i] * x[:i]) + np.sum(A[i, i+1:] * x[i+1:])
            x_new[i] = (b[i] - suma) / A[i, i]

        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, trajectory

        x = x_new
        trajectory.append(x.copy())
        logging.info(f"Iteración {k}: {x}")

    return x, trajectory

def gauss_seidel(
    *, A: np.array, b: np.array, x0: np.array, tol: float, max_iter: int
) -> tuple:
    n = A.shape[0]
    x = x0.copy()
    trajectory = [x.copy()]

    for k in range(max_iter):
        x_new = x.copy()
        for i in range(n):
            suma = np.sum(A[i, :i] * x_new[:i]) + np.sum(A[i, i+1:] * x[i+1:])
            x_new[i] = (b[i] - suma) / A[i, i]

        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, trajectory

        x = x_new
        trajectory.append(x.copy())
        logging.info(f"Iteración {k}: {x}")

    return x, trajectory

# Función para graficar la trayectoria
def plot_trajectory(trajectory, solution, method):
    trajectory = np.array(trajectory)
    plt.plot(trajectory[:, 0], trajectory[:, 1], marker='o', label=f'{method} trayectoria')
    plt.plot(solution[0], solution[1], 'ro', label='solución')
    plt.xlabel('$x_1$')
    plt.ylabel('$x_2$')
    plt.legend()
    plt.grid()
    plt.title(f'Trayectoria del método {method}')
    plt.show()

# Definir el sistema de ecuaciones
A = np.array([[1, 1], [-2, 1]])
b = np.array([6, 0])
x0 = np.array([0, 0])

# Gauss-Jacobi
solution_jacobi, trajectory_jacobi = gauss_jacobi(A=A, b=b, x0=x0, tol=1e-5, max_iter=100)
print(f'Solución Gauss-Jacobi: {solution_jacobi}')
plot_trajectory(trajectory_jacobi, solution_jacobi, 'Gauss-Jacobi')

# Gauss-Seidel
solution_seidel, trajectory_seidel = gauss_seidel(A=A, b=b, x0=x0, tol=1e-5, max_iter=100)
print(f'Solución Gauss-Seidel: {solution_seidel}')
plot_trajectory(trajectory_seidel, solution_seidel, 'Gauss-Seidel')
# Out:
# [07-19 22:56:24][INFO] 2024-07-19 22:56:24.424636
# [07-19 22:56:24][INFO] Iteración 0: [6. 0.]
# [07-19 22:56:24][INFO] Iteración 1: [ 6. 12.]
# [07-19 22:56:24][INFO] Iteración 2: [-6. 12.]
# [07-19 22:56:24][INFO] Iteración 3: [ -6. -12.]
# [07-19 22:56:24][INFO] Iteración 4: [ 18. -12.]
# [07-19 22:56:24][INFO] Iteración 5: [18. 36.]
# [07-19 22:56:24][INFO] Iteración 6: [-30.  36.]
# [07-19 22:56:24][INFO] Iteración 7: [-30. -60.]
# [07-19 22:56:24][INFO] Iteración 8: [ 66. -60.]
# [07-19 22:56:24][INFO] Iteración 9: [ 66. 132.]
# [07-19 22:56:24][INFO] Iteración 10: [-126.  132.]
# [07-19 22:56:24][INFO] Iteración 11: [-126. -252.]
# [07-19 22:56:24][INFO] Iteración 12: [ 258. -252.]
# [07-19 22:56:24][INFO] Iteración 13: [258. 516.]
# [07-19 22:56:24][INFO] Iteración 14: [-510.  516.]
# [07-19 22:56:24][INFO] Iteración 15: [ -510. -1020.]
# [07-19 22:56:24][INFO] Iteración 16: [ 1026. -1020.]
# [07-19 22:56:24][INFO] Iteración 17: [1026. 2052.]
# [07-19 22:56:24][INFO] Iteración 18: [-2046.  2052.]
# [07-19 22:56:24][INFO] Iteración 19: [-2046. -4092.]
# [07-19 22:56:24][INFO] Iteración 20: [ 4098. -4092.]
# [07-19 22:56:24][INFO] Iteración 21: [4098. 8196.]
# [07-19 22:56:24][INFO] Iteración 22: [-8190.  8196.]
# [07-19 22:56:24][INFO] Iteración 23: [ -8190. -16380.]
# [07-19 22:56:24][INFO] Iteración 24: [ 16386. -16380.]
# [07-19 22:56:24][INFO] Iteración 25: [16386. 32772.]
# [07-19 22:56:24][INFO] Iteración 26: [-32766.  32772.]
# [07-19 22:56:24][INFO] Iteración 27: [-32766. -65532.]
# [07-19 22:56:24][INFO] Iteración 28: [ 65538. -65532.]
# [07-19 22:56:24][INFO] Iteración 29: [ 65538. 131076.]
# [07-19 22:56:24][INFO] Iteración 30: [-131070.  131076.]
# [07-19 22:56:24][INFO] Iteración 31: [-131070. -262140.]
# [07-19 22:56:24][INFO] Iteración 32: [ 262146. -262140.]
# [07-19 22:56:24][INFO] Iteración 33: [262146. 524292.]
# [07-19 22:56:24][INFO] Iteración 34: [-524286.  524292.]
# [07-19 22:56:24][INFO] Iteración 35: [ -524286. -1048572.]
# [07-19 22:56:24][INFO] Iteración 36: [ 1048578. -1048572.]
# [07-19 22:56:24][INFO] Iteración 37: [1048578. 2097156.]
# [07-19 22:56:24][INFO] Iteración 38: [-2097150.  2097156.]
# [07-19 22:56:24][INFO] Iteración 39: [-2097150. -4194300.]
# [07-19 22:56:24][INFO] Iteración 40: [ 4194306. -4194300.]
# [07-19 22:56:24][INFO] Iteración 41: [4194306. 8388612.]
# [07-19 22:56:24][INFO] Iteración 42: [-8388606.  8388612.]
# [07-19 22:56:24][INFO] Iteración 43: [ -8388606. -16777212.]
# [07-19 22:56:24][INFO] Iteración 44: [ 16777218. -16777212.]
# [07-19 22:56:24][INFO] Iteración 45: [16777218. 33554436.]
# [07-19 22:56:24][INFO] Iteración 46: [-33554430.  33554436.]
# [07-19 22:56:24][INFO] Iteración 47: [-33554430. -67108860.]
# [07-19 22:56:24][INFO] Iteración 48: [ 67108866. -67108860.]
# [07-19 22:56:24][INFO] Iteración 49: [6.71088660e+07 1.34217732e+08]
# [07-19 22:56:24][INFO] Iteración 50: [-1.34217726e+08  1.34217732e+08]
# [07-19 22:56:24][INFO] Iteración 51: [-1.34217726e+08 -2.68435452e+08]
# [07-19 22:56:24][INFO] Iteración 52: [ 2.68435458e+08 -2.68435452e+08]
# [07-19 22:56:24][INFO] Iteración 53: [2.68435458e+08 5.36870916e+08]
# [07-19 22:56:24][INFO] Iteración 54: [-5.36870910e+08  5.36870916e+08]
# [07-19 22:56:24][INFO] Iteración 55: [-5.36870910e+08 -1.07374182e+09]
# [07-19 22:56:24][INFO] Iteración 56: [ 1.07374183e+09 -1.07374182e+09]
# [07-19 22:56:24][INFO] Iteración 57: [1.07374183e+09 2.14748365e+09]
# [07-19 22:56:24][INFO] Iteración 58: [-2.14748365e+09  2.14748365e+09]
# [07-19 22:56:24][INFO] Iteración 59: [-2.14748365e+09 -4.29496729e+09]
# [07-19 22:56:24][INFO] Iteración 60: [ 4.29496730e+09 -4.29496729e+09]
# [07-19 22:56:24][INFO] Iteración 61: [4.2949673e+09 8.5899346e+09]
# [07-19 22:56:24][INFO] Iteración 62: [-8.58993459e+09  8.58993460e+09]
# [07-19 22:56:24][INFO] Iteración 63: [-8.58993459e+09 -1.71798692e+10]
# [07-19 22:56:24][INFO] Iteración 64: [ 1.71798692e+10 -1.71798692e+10]
# [07-19 22:56:24][INFO] Iteración 65: [1.71798692e+10 3.43597384e+10]
# [07-19 22:56:24][INFO] Iteración 66: [-3.43597384e+10  3.43597384e+10]
# [07-19 22:56:24][INFO] Iteración 67: [-3.43597384e+10 -6.87194767e+10]
# [07-19 22:56:24][INFO] Iteración 68: [ 6.87194767e+10 -6.87194767e+10]
# [07-19 22:56:24][INFO] Iteración 69: [6.87194767e+10 1.37438953e+11]
# [07-19 22:56:24][INFO] Iteración 70: [-1.37438953e+11  1.37438953e+11]
# [07-19 22:56:24][INFO] Iteración 71: [-1.37438953e+11 -2.74877907e+11]
# [07-19 22:56:24][INFO] Iteración 72: [ 2.74877907e+11 -2.74877907e+11]
# [07-19 22:56:24][INFO] Iteración 73: [2.74877907e+11 5.49755814e+11]
# [07-19 22:56:24][INFO] Iteración 74: [-5.49755814e+11  5.49755814e+11]
# [07-19 22:56:24][INFO] Iteración 75: [-5.49755814e+11 -1.09951163e+12]
# [07-19 22:56:24][INFO] Iteración 76: [ 1.09951163e+12 -1.09951163e+12]
# [07-19 22:56:24][INFO] Iteración 77: [1.09951163e+12 2.19902326e+12]
# [07-19 22:56:24][INFO] Iteración 78: [-2.19902326e+12  2.19902326e+12]
# [07-19 22:56:24][INFO] Iteración 79: [-2.19902326e+12 -4.39804651e+12]
# [07-19 22:56:24][INFO] Iteración 80: [ 4.39804651e+12 -4.39804651e+12]
# [07-19 22:56:24][INFO] Iteración 81: [4.39804651e+12 8.79609302e+12]
# [07-19 22:56:24][INFO] Iteración 82: [-8.79609302e+12  8.79609302e+12]
# [07-19 22:56:24][INFO] Iteración 83: [-8.79609302e+12 -1.75921860e+13]
# [07-19 22:56:24][INFO] Iteración 84: [ 1.7592186e+13 -1.7592186e+13]
# [07-19 22:56:24][INFO] Iteración 85: [1.75921860e+13 3.51843721e+13]
# [07-19 22:56:24][INFO] Iteración 86: [-3.51843721e+13  3.51843721e+13]
# [07-19 22:56:24][INFO] Iteración 87: [-3.51843721e+13 -7.03687442e+13]
# [07-19 22:56:24][INFO] Iteración 88: [ 7.03687442e+13 -7.03687442e+13]
# [07-19 22:56:24][INFO] Iteración 89: [7.03687442e+13 1.40737488e+14]
# [07-19 22:56:24][INFO] Iteración 90: [-1.40737488e+14  1.40737488e+14]
# [07-19 22:56:24][INFO] Iteración 91: [-1.40737488e+14 -2.81474977e+14]
# [07-19 22:56:24][INFO] Iteración 92: [ 2.81474977e+14 -2.81474977e+14]
# [07-19 22:56:24][INFO] Iteración 93: [2.81474977e+14 5.62949953e+14]
# [07-19 22:56:24][INFO] Iteración 94: [-5.62949953e+14  5.62949953e+14]
# [07-19 22:56:24][INFO] Iteración 95: [-5.62949953e+14 -1.12589991e+15]
# [07-19 22:56:24][INFO] Iteración 96: [ 1.12589991e+15 -1.12589991e+15]
# [07-19 22:56:24][INFO] Iteración 97: [1.12589991e+15 2.25179981e+15]
# [07-19 22:56:24][INFO] Iteración 98: [-2.25179981e+15  2.25179981e+15]
# [07-19 22:56:24][INFO] Iteración 99: [-2.25179981e+15 -4.50359963e+15]
# Solución Gauss-Jacobi: [-2.25179981e+15 -4.50359963e+15]
# [07-19 22:56:24][INFO] Iteración 0: [ 6 12]
# [07-19 22:56:24][INFO] Iteración 1: [ -6 -12]
# [07-19 22:56:24][INFO] Iteración 2: [18 36]
# [07-19 22:56:24][INFO] Iteración 3: [-30 -60]
# [07-19 22:56:24][INFO] Iteración 4: [ 66 132]
# [07-19 22:56:24][INFO] Iteración 5: [-126 -252]
# [07-19 22:56:24][INFO] Iteración 6: [258 516]
# [07-19 22:56:24][INFO] Iteración 7: [ -510 -1020]
# [07-19 22:56:24][INFO] Iteración 8: [1026 2052]
# [07-19 22:56:24][INFO] Iteración 9: [-2046 -4092]
# [07-19 22:56:24][INFO] Iteración 10: [4098 8196]
# [07-19 22:56:24][INFO] Iteración 11: [ -8190 -16380]
# [07-19 22:56:24][INFO] Iteración 12: [16386 32772]
# [07-19 22:56:24][INFO] Iteración 13: [-32766 -65532]
# [07-19 22:56:24][INFO] Iteración 14: [ 65538 131076]
# [07-19 22:56:24][INFO] Iteración 15: [-131070 -262140]
# [07-19 22:56:24][INFO] Iteración 16: [262146 524292]
# [07-19 22:56:24][INFO] Iteración 17: [ -524286 -1048572]
# [07-19 22:56:24][INFO] Iteración 18: [1048578 2097156]
# [07-19 22:56:24][INFO] Iteración 19: [-2097150 -4194300]
# [07-19 22:56:24][INFO] Iteración 20: [4194306 8388612]
# [07-19 22:56:24][INFO] Iteración 21: [ -8388606 -16777212]
# [07-19 22:56:24][INFO] Iteración 22: [16777218 33554436]
# [07-19 22:56:24][INFO] Iteración 23: [-33554430 -67108860]
# [07-19 22:56:24][INFO] Iteración 24: [ 67108866 134217732]
# [07-19 22:56:24][INFO] Iteración 25: [-134217726 -268435452]
# [07-19 22:56:24][INFO] Iteración 26: [268435458 536870916]
# [07-19 22:56:24][INFO] Iteración 27: [ -536870910 -1073741820]
# [07-19 22:56:24][INFO] Iteración 28: [ 1073741826 -2147483644]
# [07-19 22:56:24][INFO] Iteración 29: [-2147483646           4]
# [07-19 22:56:24][INFO] Iteración 30: [2 4]
# Solución Gauss-Seidel: [2 4]
# C:\Users\joelq\AppData\Local\Temp\ipykernel_10700\24410595.py:58: RuntimeWarning: overflow encountered in scalar subtract
#   x_new[i] = (b[i] - suma) / A[i, i]
